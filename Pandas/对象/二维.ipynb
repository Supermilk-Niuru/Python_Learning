# %%
import pandas as pd

# %%
# 字典创建法 ： 每次给的是一个特征所有样本的数据，然后再拼接
# 按列思考

v1 = [12,13,4,5] # age
i = [1,2,3,4]
sr1 = pd.Series(v1,index = i)
print(sr1)

v2 = ['male','famale','male','female']
sr2 = pd.Series(v2,index = i)
print(sr2)

df = pd.DataFrame({'age':sr1,'sex':sr2})
print(df)
# Out:
# 1    12
# 2    13
# 3     4
# 4     5
# dtype: int64
# 1      male
# 2    famale
# 3      male
# 4    female
# dtype: object
#    age     sex
# 1   12    male
# 2   13  famale
# 3    4    male
# 4    5  female

# %%
# 二维列表创建法 ： 直接给的是一个样本的所有数据
# 按行思考
v = [[12,'male'],[13,'female'],[4,'male'],[5,'female']]
i = [1,2,3,4]
col = ['age','sex']
df = pd.DataFrame(v,columns = col,index = i)
print(df)
# Out:
#    age     sex
# 1   12    male
# 2   13  female
# 3    4    male
# 4    5  female

# %%
# 查看属性
df.values
# Out:
# array([[12, 'male'],
#        [13, 'female'],
#        [4, 'male'],
#        [5, 'female']], dtype=object)

# %% [markdown]
# **通过属性（attribute）得到的通常是一个 Python 对象，可以继续参与计算和调用方法；而 print() 展示的是这个对象转换后的文本，只用于人阅读。**

# %%
df.index
# Out:
# Index([1, 2, 3, 4], dtype='int64')

# %%
df.columns
# Out:
# Index(['age', 'sex'], dtype='object')

# %%
print(df.values) # pandas是建立在numpy基础上的。此时输出结果就是矩阵
print(df.index)
print(df.columns)
# Out:
# [[12 'male']
#  [13 'female']
#  [4 'male']
#  [5 'female']]
# Index([1, 2, 3, 4], dtype='int64')
# Index(['age', 'sex'], dtype='object')

# %%
import numpy as np

# %%
# 创建一维数组
arr1 = np.array([1,2,3])
print(arr1)
# Out:
# [1 2 3]

# %%
# 创建行矩阵
arr2 = np.array([[1,2,3]])
print(arr2)
# Out:
# [[1 2 3]]

# %%
# 创建列矩阵
arr3 = np.array([[1],[2],[3]])
print(arr3)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
# 创建矩阵
arr4 = np.array([[1,2,3],[4,5,6]])
print(arr4)
# Out:
# [[1 2 3]
#  [4 5 6]]
